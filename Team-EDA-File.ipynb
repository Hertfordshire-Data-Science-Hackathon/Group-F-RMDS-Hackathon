# %%
# Import required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import RobustScaler, OneHotEncoder,OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score, roc_curve, recall_score, precision_score, f1_score

# Hide warnings in the notebook
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Set dataset url
test_url = 'https://raw.githubusercontent.com/Hertfordshire-Data-Science-Hackathon/Group-F-RMDS-Hackathon/refs/heads/main/dataset_A_testing.csv'

training_url = 'https://raw.githubusercontent.com/Hertfordshire-Data-Science-Hackathon/Group-F-RMDS-Hackathon/refs/heads/main/dataset_A_training.csv'

# %%
# Preview data
df_vaccine = pd.read_csv(training_url)

df_vaccine.sample(10)
# Out:
#       respondent_id  flu_concern  flu_knowledge  behavioral_antiviral_meds  \
# 654             655          2.0            0.0                        0.0
# 331             332          0.0            1.0                        0.0
# 3187           3188          0.0            1.0                        0.0
# 1058           1059          2.0            1.0                        0.0
# 3649           3650          2.0            1.0                        0.0
# 4687           4688          1.0            1.0                        0.0
# 1853           1854          0.0            2.0                        0.0
# 3438           3439          0.0            2.0                        0.0
# 4171           4172          2.0            1.0                        0.0
# 2120           2121          3.0            2.0                        0.0
#
#       behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 654                    0.0                   0.0                    0.0
# 331                    1.0                   0.0                    1.0
# 3187                   1.0                   0.0                    0.0
# 1058                   1.0                   0.0                    0.0
# 3649                   1.0                   0.0                    1.0
# 4687                   1.0                   0.0                    1.0
# 1853                   0.0                   0.0                    1.0
# 3438                   0.0                   0.0                    1.0
# 4171                   1.0                   0.0                    1.0
# 2120                   1.0                   0.0                    0.0
#
#       behavioral_large_gatherings  behavioral_outside_home  \
# 654                           1.0                      1.0
# 331                           0.0                      0.0
# 3187                          0.0                      0.0
# 1058                          0.0                      0.0
# 3649                          1.0                      1.0
# 4687                          0.0                      0.0
# 1853                          1.0                      1.0
# 3438                          0.0                      1.0
# 4171                          0.0                      1.0
# 2120                          0.0                      0.0
#
#       behavioral_touch_face  ...     sex             income_poverty  \
# 654                     0.0  ...  Female  <= $75,000, Above Poverty
# 331                     0.0  ...  Female                        NaN
# 3187                    0.0  ...    Male              Below Poverty
# 1058                    1.0  ...    Male  <= $75,000, Above Poverty
# 3649                    1.0  ...  Female                        NaN
# 4687                    1.0  ...  Female                        NaN
# 1853                    1.0  ...    Male              Below Poverty
# 3438                    0.0  ...    Male                        NaN
# 4171                    1.0  ...    Male                        NaN
# 2120                    1.0  ...  Female  <= $75,000, Above Poverty
#
#       marital_status  rent_or_own   employment_status  \
# 654          Married          Own  Not in Labor Force
# 331              NaN          NaN                 NaN
# 3187     Not Married         Rent          Unemployed
# 1058         Married          Own          Unemployed
# 3649             NaN          NaN                 NaN
# 4687         Married          Own  Not in Labor Force
# 1853     Not Married          Own          Unemployed
# 3438     Not Married         Rent  Not in Labor Force
# 4171             NaN          NaN                 NaN
# 2120         Married          Own  Not in Labor Force
#
#                     census_msa  household_adults  household_children  \
# 654                    Non-MSA               2.0                 0.0
# 331   MSA, Not Principle  City               1.0                 2.0
# 3187       MSA, Principle City               1.0                 0.0
# 1058  MSA, Not Principle  City               2.0                 3.0
# 3649  MSA, Not Principle  City               1.0                 0.0
# 4687  MSA, Not Principle  City               3.0                 0.0
# 1853       MSA, Principle City               0.0                 0.0
# 3438                   Non-MSA               3.0                 0.0
# 4171                   Non-MSA               1.0                 3.0
# 2120  MSA, Not Principle  City               1.0                 0.0
#
#      employment_sector seasonal_vaccine
# 654                NaN                0
# 331                NaN                0
# 3187               NaN                0
# 1058               NaN                0
# 3649               NaN                1
# 4687               NaN                1
# 1853               NaN                0
# 3438               NaN                0
# 4171               NaN                0
# 2120               NaN                1
#
# [10 rows x 31 columns]
