# %% [markdown]
# <a href="https://colab.research.google.com/github/Hertfordshire-Data-Science-Hackathon/Group-F-RMDS-Hackathon/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import warnings
import numpy as np
import pandas as pd

from sklearn.base import clone
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    HistGradientBoostingClassifier
)

warnings.filterwarnings("ignore")

# %%
df_train=pd.read_csv('dataset_A_training.csv')

# %%
print(df_train.head(10))
# Out:
#    respondent_id  flu_concern  flu_knowledge  behavioral_antiviral_meds  \
# 0              1          2.0            0.0                        0.0
# 1              2          1.0            1.0                        0.0
# 2              3          2.0            1.0                        0.0
# 3              4          1.0            2.0                        0.0
# 4              5          2.0            2.0                        0.0
# 5              6          0.0            1.0                        0.0
# 6              7          3.0            2.0                        0.0
# 7              8          2.0            1.0                        0.0
# 8              9          2.0            1.0                        0.0
# 9             10          2.0            1.0                        0.0
#
#    behavioral_avoidance  behavioral_face_mask  behavioral_wash_hands  \
# 0                   1.0                   0.0                    1.0
# ...
